# %%
a, b = 1, 12
x=0
while ((a+x)%b==0 and (b+x)%a==0)==False:
    x+=1
print(x)
# Out:
# Running cells with '.myenv (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/MIPT/IT-1/.myenv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
